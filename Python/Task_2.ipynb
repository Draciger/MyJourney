# %% [markdown]
# ### Task 2
# Here is a list of hospitals located in Norway, see link here:
# https://en.wikipedia.org/wiki/List_of_hospitals_in_Norway. Perform the following task:
# a. Create a Series from Pandas, where information on Oslo University Hospital should be
# included, i.e., hospital name, major location, main campuses, description and/or other
# relevant information
# b. Choose 16 hospitals from the above list, and then create 16 Series, each of which
# includes information about that hospital
# c. Create a DataFrame from the Series generated from step b.
# d. Generate a new column, named ‘Regional Health Authority’. For each row in
# DataFrame created from step c, assign a corresponding value for ‘Regional Health
# Authority’.
# For example, for ‘Oslo University Hospital’, the value of ‘Regional Health Authority’ should
# be filled with ‘Southern and Eastern Norway Regional Health Authority’

# %%
import pandas as pd

# %%
# a)
# Information for Oslo University Hospital
info_Uni_Oslo_hospital = {
    'Hospital Name': 'Oslo University Hospital',
    'Major Location': 'Oslo, Norway',
    'Main Campuses': ['Rikshospitalet', 'Aker', 'Ullevål'],
    'Employees': 24000,
    'Type': 'University Hospital',
    'Founded': 2009
}

# Creating a Series
Uni_Oslo_hospital_series = pd.Series(info_Uni_Oslo_hospital)
print(Uni_Oslo_hospital_series)
print()
print(Uni_Oslo_hospital_series.info())
# Out:
# Hospital Name            Oslo University Hospital
# Major Location                       Oslo, Norway
# Main Campuses     [Rikshospitalet, Aker, Ullevål]
# Employees                                   24000
# Type                          University Hospital
# Founded                                      2009
# dtype: object
#
# <class 'pandas.core.series.Series'>
# Index: 6 entries, Hospital Name to Founded
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      object
# dtypes: object(1)
# memory usage: 96.0+ bytes
# None

# %%
# b)
# Creating 16 series with different hospitals in Norway
info_Voss_Hospital = {
    'Hospital Name': 'Voss Hospital',
    'Major Location': 'Voss, Norway',
    'Main Campuses': ['Voss'],
    'Employees': 14000,
    'Type': 'General',
    'Founded': 1990
}
Voss_Hospital_series = pd.Series(info_Voss_Hospital)

info_Nord_Trondelag_Hospital_Trust = {
    'Hospital Name': 'Nord-Trøndelag Hospital Trust',
    'Major Location': 'Levanger, Norway',
    'Main Campuses': ['Stjørdal' 'Kolvereid'],
    'Employees': 2500,
    'Type': 'Health Trust',
    'Founded': 2002
}
Nord_Trondelag_Hospital_Trust_series = pd.Series(info_Nord_Trondelag_Hospital_Trust)

info_St_Olavs_University_Hospital = {
    'Hospital Name': 'St. Olavs University Hospital',
    'Major Location': 'Trondheim, Norway',
    'Main Campuses': ['Trondheim, Oya'],
    'Employees': 8600,
    'Type': 'Teaching',
    'Founded': 1902
}
St_Olavs_University_Hospital_series = pd.Series(info_St_Olavs_University_Hospital)

info_Ålesund_Hospital = {
    'Hospital Name': 'Ålesund Hospital',
    'Major Location': 'Ålesund, Norway',
    'Main Campuses': ['Ålesund'],
    'Employees': 500,
    'Type': 'General',
    'Founded': 2002
}    
Ålesund_Hospital_series = pd.Series(info_Ålesund_Hospital)

info_University_Hospital_of_North_Norway = {
    'Hospital Name': 'University Hospital of North Norway',
    'Major Location': 'Tromsø, Norway',
    'Main Campuses': ['Nordland, Troms, Finnmark'],
    'Employees': 5700,
    'Type': 'Health trust',
    'Founded': 2001
}
University_Hospital_of_North_Norway_series = pd.Series(info_University_Hospital_of_North_Norway)

info_Odda_Hospital = {
    'Hospital Name': 'Odda Hospital',
    'Major Location': 'Odda, Norway',
    'Main Campuses': ['Odda'],
    'Employees': 430,
    'Type': 'General',
    'Founded': 2007
}
Odda_Hospital_series = pd.Series(info_Odda_Hospital)

info_Vestfold_Hospital_Trust = {
    'Hospital Name': 'Vestfold Hospital Trust',
    'Major Location': 'Vestfold, Norway',
    'Main Campuses': ['Vestfold'],
    'Employees': 5400,
    'Type': 'Health trust',
    'Founded': 2002
}
Vestfold_Hospital_Trust_series = pd.Series(info_Vestfold_Hospital_Trust)

info_Vestre_Viken_Hospital_Trust = {
    'Hospital Name': 'Vestre Viken Hospital Trust',
    'Major Location': 'Drammen, Norway',
    'Main Campuses': ['Buskerud, Asker, Bærum'],
    'Employees': 9500,
    'Type': 'General',
    'Founded': 1878
}
Vestre_Viken_Hospital_Trust_series = pd.Series(info_Vestre_Viken_Hospital_Trust)

info_Southern_and_Eastern_Norway_Pharmaceutical_Trust = {
    'Hospital Name': 'Southern and Eastern Norway Pharmaceutical Trust',
    'Major Location': 'Oslo, Norway',
    'Main Campuses': ['Oslo'],
    'Employees': 600,
    'Type': 'Health trust',
    'Founded': 2002
}
Southern_and_Eastern_Norway_Pharmaceutical_Trust_series = pd.Series(info_Southern_and_Eastern_Norway_Pharmaceutical_Trust)

info_Molde_Hospital = {
    'Hospital Name': 'Molde Hospital',
    'Major Location': 'Molde, Norway',
    'Main Campuses': ['Molde'],
    'Employees': 1600,
    'Type': 'General',
    'Founded': 2002
}
Molde_Hospital_series = pd.Series(info_Molde_Hospital)

info_Bergen_Hospital_Trust = {
    'Hospital Name': 'Bergen Hospital Trust',
    'Major Location': 'Bergen, Norway',
    'Main Campuses': ['Bergen'],
    'Employees': 12300,
    'Type': 'Health trust',
    'Founded': 2002
}
Bergen_Hospital_Trust_series = pd.Series(info_Bergen_Hospital_Trust)

info_Fonna_Hospital_Trust = {
    'Hospital Name': 'Fonna Hospital Trust',
    'Major Location': 'Haugesund, Norway',
    'Main Campuses': ['Haugaland, Sunnhordland, Hardanger'],
    'Employees': 3333,
    'Type': 'State owned',
    'Founded': 2002
}
Fonna_Hospital_Trust_series = pd.Series(info_Fonna_Hospital_Trust)

info_Førde_Hospital_Trust = {
    'Hospital Name': 'Førde Hospital Trust',
    'Major Location': 'Fjordane, Norway',
    'Main Campuses': ['Sogn, Fjordane'],
    'Employees': 2300,
    'Type': 'State owned',
    'Founded': 2002
}
Førde_Hospital_Trust_series = pd.Series(info_Førde_Hospital_Trust)

info_Stavanger_University_Hospital = {
    'Hospital Name': 'Stavanger University Hospital',
    'Major Location': 'Stavanger, Norway',
    'Main Campuses': ['Våland, Stavanger'],
    'Employees': 7500,
    'Type': 'General',
    'Founded': 2002
}
Stavanger_University_Hospital_series = pd.Series(info_Stavanger_University_Hospital)

info_Privatsykehuset_Haugesund = {
    'Hospital Name': 'Privatsykehuset Haugesund',
    'Major Location': 'Rogaland, Norway',
    'Main Campuses': ['Rogaland'],
    'Employees': 50,
    'Type': 'Private General',
    'Founded': 1997
}
Privatsykehuset_Haugesund_series = pd.Series(info_Privatsykehuset_Haugesund)

info_Skogli_Health_And_Rehabilitation_Center = {
    'Hospital Name': 'Skogli Health And Rehabilitation Center',
    'Major Location': 'Lillehammer, Norway',
    'Main Campuses': ['Lillehammer'],
    'Employees': 80,
    'Type': 'Private Health',
    'Founded': 1979
}
Skogli_Health_And_Rehabilitation_Center_series = pd.Series(info_Skogli_Health_And_Rehabilitation_Center)

# %%
# c)
# Create a DataFrame from the Series generated from step b

df_hospitals = pd.DataFrame([Privatsykehuset_Haugesund_series, Stavanger_University_Hospital_series, Førde_Hospital_Trust_series, Fonna_Hospital_Trust_series, Bergen_Hospital_Trust_series, Molde_Hospital_series, Southern_and_Eastern_Norway_Pharmaceutical_Trust_series, Vestre_Viken_Hospital_Trust_series, Vestfold_Hospital_Trust_series, University_Hospital_of_North_Norway_series, Ålesund_Hospital_series, St_Olavs_University_Hospital_series, Nord_Trondelag_Hospital_Trust_series, Voss_Hospital_series, Uni_Oslo_hospital_series, Odda_Hospital_series, Skogli_Health_And_Rehabilitation_Center_series])

print(df_hospitals)
# Out:
#                                        Hospital Name       Major Location  \
# 0                          Privatsykehuset Haugesund     Rogaland, Norway
# 1                      Stavanger University Hospital    Stavanger, Norway
# 2                               Førde Hospital Trust     Fjordane, Norway
# 3                               Fonna Hospital Trust    Haugesund, Norway
# 4                              Bergen Hospital Trust       Bergen, Norway
# 5                                     Molde Hospital        Molde, Norway
# 6   Southern and Eastern Norway Pharmaceutical Trust         Oslo, Norway
# 7                        Vestre Viken Hospital Trust      Drammen, Norway
# 8                            Vestfold Hospital Trust     Vestfold, Norway
# 9                University Hospital of North Norway       Tromsø, Norway
# 10                                  Ålesund Hospital      Ålesund, Norway
# 11                     St. Olavs University Hospital    Trondheim, Norway
# ...

# %%
# d)
# adding a column with Generate a new column, named ‘Regional Health Authority’. For each row in DataFrame created from step 
# c, assign a corresponding value for ‘Regional Health Authority’.

# Creating a mapping between the hospital and the new
regional_health_authorities = {
    'Voss Hospital': 'Western Norway Regional Health Authority',
    'Nord-Trøndelag Hospital Trust': 'Central Norway Regional Health Authority',
    'St. Olavs University Hospital': 'Central Norway Regional Health Authority',
    'Ålesund Hospital': 'Central Norway Regional Health Authority',
    'University Hospital of North Norway': 'Northern Norway Regional Health Authority',
    'Odda Hospital': 'Western Norway Regional Health Authority',
    'Vestfold Hospital Trust': 'Southern and Eastern Norway Regional Health Authority',
    'Vestre Viken Hospital Trust': 'Southern and Eastern Norway Regional Health Authority',
    'Southern and Eastern Norway Pharmaceutical Trust': 'Southern and Eastern Norway Regional Health Authorit',
    'Molde Hospital': 'Central Norway Regional Health Authority',
    'Bergen Hospital Trust': 'Western Norway Regional Health Authority',
    'Fonna Hospital Trust': 'Western Norway Regional Health Authority',
    'Førde Hospital Trust': 'Western Norway Regional Health Authority',
    'Stavanger University Hospital': 'Western Norway Regional Health Authority',
    'Privatsykehuset Haugesund': 'Western Norway Regional Health Authority',
    'Skogli Health And Rehabilitation Center': 'Southern and Eastern Norway Regional Health Authority',
    'Oslo University Hospital': 'Southern and Eastern Norway Regional Health Authority'
}

# add the new data to the data frame
df_hospitals['Regional Health Authority'] = df_hospitals['Hospital Name'].map(regional_health_authorities)

df_hospitals
# Out:
#                                        Hospital Name       Major Location  \
# 0                          Privatsykehuset Haugesund     Rogaland, Norway
# 1                      Stavanger University Hospital    Stavanger, Norway
# 2                               Førde Hospital Trust     Fjordane, Norway
# 3                               Fonna Hospital Trust    Haugesund, Norway
# 4                              Bergen Hospital Trust       Bergen, Norway
# 5                                     Molde Hospital        Molde, Norway
# 6   Southern and Eastern Norway Pharmaceutical Trust         Oslo, Norway
# 7                        Vestre Viken Hospital Trust      Drammen, Norway
# 8                            Vestfold Hospital Trust     Vestfold, Norway
# 9                University Hospital of North Norway       Tromsø, Norway
# 10                                  Ålesund Hospital      Ålesund, Norway
# 11                     St. Olavs University Hospital    Trondheim, Norway
# ...
